# %%
import pandas as pd
import numpy as np

# %%
df_clientes = pd.read_excel(r'C:\Users\fedec\OneDrive\Desktop\contenido\py\DS\CASO PRÁCTICO 1\Clientes.xlsx',sheet_name = "Sheet1")
df_clientes
# Out:
#     ID Cliente     Nombre cliente     Segmento           País  \
# 0     CG-12520        Claire Gute     Consumer  United States
# 1     DV-13045    Darrin Van Huff    Corporate  United States
# 2     SO-20335     Sean O'Donnell     Consumer  United States
# 3     BH-11710    Brosina Hoffman     Consumer  United States
# 4     AA-10480       Andrew Allen     Consumer  United States
# ..         ...                ...          ...            ...
# 788   CJ-11875       Carl Jackson    Corporate        Romania
# 789   RS-19870         Roy Skaria  Home Office        Romania
# 790   SC-20845         Sung Chung     Consumer        Romania
# 791   RE-19405    Ricardo Emerson     Consumer        Romania
# 792   SM-20905  Susan MacKendrick     Consumer        Romania
#
#               Ciudad          Estado  Código Postal Región
# 0          Henderson        Kentucky        42420.0  South
# 1        Los Angeles      California        90036.0   West
# ...

# %%
df_Productos = pd.read_excel(r'C:\Users\fedec\OneDrive\Desktop\contenido\py\DS\CASO PRÁCTICO 1\Productos.xlsx',sheet_name = "Sheet1")
df_Productos
# Out:
#           ID Producto        Categoría Sub-categoría  \
# 0     FUR-BO-10001798        Furniture     Bookcases
# 1     FUR-CH-10000454        Furniture        Chairs
# 2     OFF-LA-10000240  Office Supplies        Labels
# 3     FUR-TA-10000577        Furniture        Tables
# 4     OFF-ST-10000760  Office Supplies       Storage
# ...               ...              ...           ...
# 1859  TEC-MA-10003589       Technology      Machines
# 1860  OFF-AP-10003099  Office Supplies    Appliances
# 1861  TEC-PH-10002645       Technology        Phones
# 1862  OFF-ST-10001627  Office Supplies       Storage
# 1863  OFF-BI-10003656  Office Supplies       Binders
#
#                                         Nombre Producto  Coste Producción
# 0                     Bush Somerset Collection Bookcase        230.098156
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...        563.102730
# 2     Self-Adhesive Address Labels for Typewriters b...         11.746474
# ...

# %%
df_ventas = pd.read_excel(r'C:\Users\fedec\OneDrive\Desktop\contenido\py\DS\CASO PRÁCTICO 1\Ventas.xlsx',sheet_name = "Sheet1")
df_ventas
# Out:
#            ID Pedido Fecha compra         Fecha envío      Modo envío  \
# 0     CA-2016-152156   2020-11-08 2020-11-11 05:00:00    Second Class
# 1     CA-2016-152156   2020-11-08 2020-11-11 00:00:00    Second Class
# 2     CA-2016-138688   2020-06-12 2020-06-16 00:00:00    Second Class
# 3     US-2015-108966   2019-10-11                 NaT  Standard Class
# 4     US-2015-108966   2019-10-11 2019-10-18 00:00:00  Standard Class
# ...              ...          ...                 ...             ...
# 9989  CA-2014-110422   2018-01-21 2018-01-23 00:00:00    Second Class
# 9990  CA-2017-121258   2021-02-26 2021-03-03 00:00:00  Standard Class
# 9991  CA-2017-121258   2021-02-26 2021-03-03 00:00:00  Standard Class
# 9992  CA-2017-121258   2021-02-26 2021-03-03 00:00:00  Standard Class
# 9993  CA-2017-119914   2021-05-04 2021-05-09 00:00:00    Second Class
#
#      ID Cliente      ID Producto Precio unitario  Cantidad
# 0      CG-12520  FUR-BO-10001798          261,96         2
# ...

# %%
df_clientes.isnull().sum()
# Out:
# ID Cliente          0
# Nombre cliente      0
# Segmento            0
# País                0
# Ciudad            455
# Estado            455
# Código Postal     455
# Región            455
# dtype: int64

# %%
df_Productos.isnull().sum()
# Out:
# ID Producto         0
# Categoría           0
# Sub-categoría       0
# Nombre Producto     1
# Coste Producción    2
# dtype: int64

# %%
df_ventas.isnull().sum()
# Out:
# ID Pedido          0
# Fecha compra       3
# Fecha envío        6
# Modo envío         0
# ID Cliente         0
# ID Producto        0
# Precio unitario    0
# Cantidad           0
# dtype: int64

# %%
# Eliminar filas donde 'Fecha compra' es nulo
df_ventas = df_ventas.dropna(subset=["Fecha compra"])

# %% [markdown]
# transformo en int las columnas con valores numericos que deben ser cambiadas
